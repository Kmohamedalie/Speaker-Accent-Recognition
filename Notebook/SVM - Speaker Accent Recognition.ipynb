# %% [markdown]
# ![image-4.png](attachment:image-4.png)
#
#
# ##  Data
# <a href="https://archive.ics.uci.edu/dataset/518/speaker+accent+recognition">UCI machine learning</a>,  <a href="https://www.kaggle.com/datasets/singhakash/speaker-accent-recognition-datasets">Kaggle</a>
#
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# * Use <a href="https://scikit-learn.org/stable/modules/svm.html">Scikit-Learn Support Vector Machine</a> algorithms to classify
#
#
# **Additional Information**
#
# Data set featuring single English words read by speakers from six different countries for accent detection and recognition
#
#
# Response variable:
# language = {ES, FR, GE, IT, UK, US} The six possible accents considered
#
# Explanatory variables:
# X1, X2, ..., X12 Obtained using MFCC on the original time domain soundtrack of the maximum 1s of reading of a word

# %% [markdown]
# <h1>Table of contents</h1>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ol>
#         <li><a href="#load_dataset">Load the  data</a></li>
#         <li><a href="#modeling">Modeling</a></li>
#         <li><a href="#evaluation">Evaluation</a></li>
#         <li><a href="#practice">Practice</a></li>
#     </ol>
# </div>
# <br>
# <hr>

# %% [markdown]
# ## import packages

# %%
#!pip install snapml

# %%
import pandas as pd
import pylab as pl
import numpy as np
import seaborn as sns
import scipy.optimize as opt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize, StandardScaler
from sklearn.utils.class_weight import compute_sample_weight
from sklearn import svm # the classifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, \
f1_score, classification_report,ConfusionMatrixDisplay, mean_squared_error # for model evaluation
# %matplotlib inline 
import matplotlib.pyplot as plt

# the dataset in sklearn
from sklearn import datasets


import pickle # save the model

# suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Load Data

# %%
## Load the dataset
speech_recognition = pd.read_csv('accent-mfcc-data-1.csv')

# %% [markdown]
# ## Basic EDA

# %%
# to rows of the dataset
speech_recognition.head()
# Out:
#   language         X1        X2        X3         X4        X5         X6  \
# 0       ES   7.071476 -6.512900  7.650800  11.150783 -7.657312  12.484021
# 1       ES  10.982967 -5.157445  3.952060  11.529381 -7.638047  12.136098
# 2       ES   7.827108 -5.477472  7.816257   9.187592 -7.172511  11.715299
# 3       ES   6.744083 -5.688920  6.546789   9.000183 -6.924963  11.710766
# 4       ES   5.836843 -5.326557  7.472265   8.847440 -6.773244  12.677218
#
#           X7        X8        X9       X10       X11       X12
# 0 -11.709772  3.426596  1.462715 -2.812753  0.866538 -5.244274
# 1 -12.036247  3.491943  0.595441 -4.508811  2.332147 -6.221857
# 2 -13.847214  4.574075 -1.687559 -7.204041 -0.011847 -6.463144
# 3 -12.374388  6.169879 -0.544747 -6.019237  1.358559 -6.356441
# 4 -12.315061  4.416344  0.193500 -3.644812  2.151239 -6.816310

# %%
# shape of the data
speech_recognition.shape
# Out:
# (329, 13)

# %% [markdown]
# **Missing values**

# %%
# check for missing values
speech_recognition.isna().any().sum()
# Out:
# 0

# %% [markdown]
# **Distribution of the dataset**

# %%
# let see if we dealing the imbalance dataset
speech_recognition['language'].value_counts()
# Out:
# US    165
# UK     45
# FR     30
# GE     30
# IT     30
# ES     29
# Name: language, dtype: int64

# %%
# let see if we dealing the imbalance dataset
speech_recognition['language'].value_counts(normalize=True)
# Out:
# US    0.501520
# UK    0.136778
# FR    0.091185
# GE    0.091185
# IT    0.091185
# ES    0.088146
# Name: language, dtype: float64

# %% [markdown]
# **Data distribution:** US make up 50.15% of the dataset

# %%
# plot of the distribution
sns.countplot(data=speech_recognition, x='language', hue='language').set(title = " Value count the languaguages");

# %% [markdown]
# ## Data pre-processing and selection, Train/Test

# %% [markdown]
# Label encode the language column:

# %%
#from sklearn import preprocessing
#le = preprocessing.LabelEncoder()
#speech_recognition['language'] = le.fit_transform(speech_recognition['language'])

# %% [markdown]
# Let's set the Target and features

# %%
#target arrays
y = speech_recognition['language']

# %%
# drop the target 
speech_recognition.drop('language', axis = 1, inplace = True)

# %%
# Create features
X = speech_recognition.copy()

# %%
# check the columns to see if we have dropped the 'Result' and 'id'
X.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11',
#        'X12'],
#       dtype='object')

# %% [markdown]
# **Train test split the dataset**

# %%
# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state=365, stratify=y)

# %% [markdown]
# Let's convert to an array so that sklearn find's it easy

# %%
# assign to the y variable
y_train = np.asarray(y_train)
y_test = np.asarray(y_test)

# %%
# assign the features
x_train = np.asarray(X_train)
x_test = np.asarray(X_test)

# %%
print ('Train set:', x_train.shape,  y_train.shape)
print ('Test set:', x_test.shape,  y_test.shape)
# Out:
# Train set: (263, 12) (263,)
# Test set: (66, 12) (66,)

# %% [markdown]
# ## Feature scaling

# %%
scaler = StandardScaler() # scaler objecy
x_train = scaler.fit_transform(x_train) # allow the scaler object to learn the features and transform the training data
x_test =  scaler.transform(x_test) # apply the learned features on the test set

# %%
# scaled x_train
x_train[0:1]
# Out:
# array([[-1.80721257,  1.10101099,  0.11133409, -0.27588342,  1.71563022,
#         -2.74687578,  0.74649815,  1.90587565, -1.74655566,  1.47979982,
#         -1.98899545,  1.06602944]])

# %%
# scaled x_test
x_test[0:1]
# Out:
# array([[-0.76854111,  1.47931428, -0.37474552, -0.8378834 ,  0.27938114,
#          0.22175248, -1.87735674,  0.66704589, -0.12715503, -0.1924211 ,
#          0.78709115, -1.00314959]])

# %% [markdown]
# <div id="svm_snap">
#     <h2>Build a Support Vector Machine classifer with scikit-learn</h2>
# </div>

# %%
svc = svm.SVC(C=5, kernel='rbf')

# %%
# train an SVM model using Snap ML
clf = svc.fit(x_train, y_train)

# %% [markdown]
# After being fitted, the model can then be used to predict new values:

# %%
yhat = clf.predict(x_test)
yhat[0:5]
# Out:
# array(['GE', 'FR', 'UK', 'US', 'UK'], dtype=object)

# %% [markdown]
# **Metrics**

# %%
svm_f1 = f1_score(y_test, yhat, average='weighted')
svm_accuracy = accuracy_score(y_test, yhat)
svm_precision = precision_score(y_test, yhat, average='micro')
#svm_mse  = mean_squared_error(y_test, yhat,multioutput='raw_values')

print("Avg F1-score: %.4f" % svm_f1)
print("Accuracy: %.4f" % svm_accuracy)
print("Precision: %.4f" % svm_precision)
#print("Means Square error: %.4f" % svm_mse)
# Out:
# Avg F1-score: 0.8168
# Accuracy: 0.8182
# Precision: 0.8182

# %% [markdown]
# **Save the SVM model:**

# %%
#save the trained model
pickle.dump(clf, open('Phishing_Websites_SVM.pkl','wb'))

# %% [markdown]
# <h2 id="evaluation">Evaluation</h2>

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools

# %%
# classification report
print (classification_report(y_test, yhat,labels=np.unique(yhat)))
# Out:
#               precision    recall  f1-score   support
#
#           ES       1.00      1.00      1.00         6
#           FR       0.67      0.33      0.44         6
#           GE       0.71      0.83      0.77         6
#           IT       0.50      0.83      0.62         6
#           UK       0.89      0.89      0.89         9
#           US       0.90      0.85      0.88        33
#
#     accuracy                           0.82        66
#    macro avg       0.78      0.79      0.77        66
# weighted avg       0.83      0.82      0.82        66

# %% [markdown]
# **Confusion Matrix display:**

# %%
# confusion matrics
disp = ConfusionMatrixDisplay.from_predictions(y_test, yhat)
disp.figure_.suptitle("Confusion Matrix")

plt.show()


print(f"Confusion matrix:\n{disp.confusion_matrix}")
# Out:
# Confusion matrix:
# [[ 6  0  0  0  0  0]
#  [ 0  2  0  2  0  2]
#  [ 0  0  5  0  0  1]
#  [ 0  1  0  5  0  0]
#  [ 0  0  1  0  8  0]
#  [ 0  0  1  3  1 28]]

# %% [markdown]
# ### **Report**

# %%
metric = {
  "Accuracy": [str(round(svm_f1*100,2))+"%"],
  "F1 score" : [str(round(svm_accuracy*100,2))+"%"],
  "Precision": [str(round(svm_precision*100,2))+"%"]
}


Report = pd.DataFrame(metric)
Report = Report.rename(index={ 0:'Support Vector Machine'})

# %%
# now print the classification report
Report
# Out:
#                        Accuracy F1 score Precision
# Support Vector Machine   81.68%   81.82%    81.82%

# %% [markdown]
# ### **Now over to you TUNE the PARAMETERS to see if the ACCURACY and F1-SCORE will improve.**

# %% [markdown]
# # Thank you for completing this lab!
